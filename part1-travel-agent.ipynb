# %% [markdown]
# # Wild Drone LLM Workshop: Part 1 - Travel Assistant Agent
#
# Outdated! - Updated version in Google Colab:
# https://colab.research.google.com/drive/11cgnpWTMLjIDlOyYQ23STOYHWmjZf5ii?usp=sharing

# %% [markdown]
# ## Setup: Get Your API Key
#
# You need a **free Gemini API key** from: https://aistudio.google.com/app/apikey
#
# **Quick Setup:**
# 1. Copy `.env.example` to `.env`
# 2. Add your key: `GEMINI_API_KEY=your_key_here`
# 3. Run the cells below
#
# **Alternative:** Set in terminal: `export GEMINI_API_KEY=your_key_here`

# %%
# Install required packages
# !pip install litellm matplotlib numpy python-dotenv

# Note: If using OpenAI instead of Gemini, also install:
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting litellm
#   Downloading litellm-1.97.0-cp310-abi3-manylinux_2_28_x86_64.whl (24.4 MB)
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/24.4 MB 15.4 MB/s eta 0:00:02
#      ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/24.4 MB 25.7 MB/s eta 0:00:01
#      ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/24.4 MB 29.8 MB/s eta 0:00:01
#      ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/24.4 MB 36.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/24.4 MB 37.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 11.0/24.4 MB 43.6 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 12.5/24.4 MB 48.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 15.6/24.4 MB 44.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 17.2/24.4 MB 45.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 18.8/24.4 MB 44.6 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 21.9/24.4 MB 44.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 23.8/24.4 MB 46.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 24.4/24.4 MB 46.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /home/alejp1998/.local/lib/python3.10/site-packages (3.10.6)
# Requirement already satisfied: numpy in /home/alejp1998/.local/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: python-dotenv in /usr/lib/python3/dist-packages (0.19.2)
# Requirement already satisfied: click<9.0,>=8.0.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from litellm) (8.3.3)
# Collecting jinja2<4.0,>=3.1.6
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 30.4 MB/s eta 0:00:00
# Collecting aiohttp<4.0,>=3.14.2
#   Downloading aiohttp-3.14.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.7 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.4 MB/s eta 0:00:00
# Requirement already satisfied: httpx<1.0,>=0.28.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from litellm) (0.28.1)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.3-py3-none-any.whl (22 kB)
# Collecting pydantic-settings<3.0,>=2.14.1
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 KB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from litellm) (2.12.5)
# Collecting openai<3.0.0,>=2.20.0
#   Downloading openai-2.54.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.7 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.2 MB/s eta 0:00:00
# Collecting importlib-metadata<9.0,>=8.0.0
#   Downloading importlib_metadata-8.9.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from litellm) (4.26.0)
# Collecting fastuuid<1.0,>=0.14.0
#   Downloading fastuuid-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 KB 36.2 MB/s eta 0:00:00
# Collecting tiktoken<1.0,>=0.8.0
#   Downloading tiktoken-0.14.0-cp310-cp310-manylinux_2_28_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.2 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from litellm) (0.22.2)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alejp1998/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from matplotlib) (26.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alejp1998/.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: attrs>=17.3.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from aiohttp<4.0,>=3.14.2->litellm) (26.1.0)
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 KB 26.1 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.5.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 KB 30.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.5/219.5 KB 38.0 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.24.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 KB 42.4 MB/s eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: typing_extensions>=4.4 in /home/alejp1998/.local/lib/python3.10/site-packages (from aiohttp<4.0,>=3.14.2->litellm) (4.15.0)
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1.0,>=0.28.0->litellm) (2020.6.20)
# Requirement already satisfied: anyio in /usr/lib/python3/dist-packages (from httpx<1.0,>=0.28.0->litellm) (3.5.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx<1.0,>=0.28.0->litellm) (3.3)
# Requirement already satisfied: httpcore==1.* in /home/alejp1998/.local/lib/python3.10/site-packages (from httpx<1.0,>=0.28.0->litellm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/alejp1998/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0,>=0.28.0->litellm) (0.16.0)
# Collecting zipp>=3.20
#   Downloading zipp-4.1.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2<4.0,>=3.1.6->litellm) (2.0.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.30.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/alejp1998/.local/lib/python3.10/site-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/alejp1998/.local/lib/python3.10/site-packages (from jsonschema<5.0,>=4.0.0->litellm) (2025.9.1)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.3/348.3 KB 36.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/lib/python3/dist-packages (from openai<3.0.0,>=2.20.0->litellm) (1.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<3.0.0,>=2.20.0->litellm) (1.7.0)
# Requirement already satisfied: tqdm>4 in /home/alejp1998/.local/lib/python3.10/site-packages (from openai<3.0.0,>=2.20.0->litellm) (4.67.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/alejp1998/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/alejp1998/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: requests in /home/alejp1998/.local/lib/python3.10/site-packages (from tiktoken<1.0,>=0.8.0->litellm) (2.32.5)
# Requirement already satisfied: regex in /home/alejp1998/.local/lib/python3.10/site-packages (from tiktoken<1.0,>=0.8.0->litellm) (2026.4.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /home/alejp1998/.local/lib/python3.10/site-packages (from tokenizers<1.0,>=0.21.0->litellm) (1.11.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/alejp1998/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.4.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (5.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (3.20.3)
# Requirement already satisfied: typer in /home/alejp1998/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.24.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->tiktoken<1.0,>=0.8.0->litellm) (1.26.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/alejp1998/.local/lib/python3.10/site-packages (from requests->tiktoken<1.0,>=0.8.0->litellm) (3.4.3)
# Requirement already satisfied: rich>=12.3.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/alejp1998/.local/lib/python3.10/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.5.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/alejp1998/.local/lib/python3.10/site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/alejp1998/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.1.2)
# Installing collected packages: zipp, python-dotenv, propcache, multidict, jiter, jinja2, frozenlist, fastuuid, async-timeout, aiohappyeyeballs, yarl, tiktoken, importlib-metadata, aiosignal, pydantic-settings, openai, aiohttp, litellm
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 async-timeout-5.0.1 fastuuid-0.14.0 frozenlist-1.8.0 importlib-metadata-8.9.0 jinja2-3.1.6 jiter-0.16.0 litellm-1.97.0 multidict-6.7.1 openai-2.54.0 propcache-0.5.2 pydantic-settings-2.15.0 python-dotenv-1.2.3 tiktoken-0.14.0 yarl-1.24.5 zipp-4.1.0

# %%
# Configuration and Setup
import os
import litellm
from dotenv import load_dotenv
from llm_agents import add_parameters_schema, LLMAgent

# Load environment variables from .env file (if it exists)
load_dotenv()

# MODEL CONFIGURATION
# Get Gemini API key from environment variable
gemini_api_key = os.getenv('GEMINI_API_KEY')
# Set the API key for litellm
os.environ['GEMINI_API_KEY'] = gemini_api_key
# Set the model to use throughout the workshop
model_name = "gemini/gemini-2.5-flash"  # Using stable model

# %% [markdown]
# # Understanding LLMs
#
# ## Your First LLM Conversation
# Let's start simple - ask an LLM a question and see how it responds.
#
# ## TO-DO 📝
# - Try modifying the system prompt to see how it affects the response
# - Try modifying the user prompt to ask different questions
# - Try modifying the temperature, how does the response look as we try higher values like 0.5, 1.0 or 2.0?

# %%
system_prompt = "You are a helpful assistant that answers with short poems."
user_prompt = "How do I make a Spanish tortilla?"

response = litellm.completion(
        model=model_name,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        max_tokens=2000, # maximum length of the response in tokens
        temperature=0.0, # 0.0 is deterministic (should always yield same response), more than 0.0 adds randomness and creativity
    )
print(response.choices[0].message.content)
# Out:
# Golden spuds, thinly sliced,
# In olive oil, gently fried.
# Onion too, if you desire,
# Soft and sweet, by the fire.
#
# Whisk the eggs, a yellow stream,
# Mix with spuds, a lovely dream.
# Into the pan, a gentle pour,
# Cook till set, then flip for more.

# %% [markdown]
# ## The Problem: LLMs Are Limited to their Training Data
#
# LLMs can't:
# - Get current weather 🌤️
# - Access the internet 🌐
#
# They will either say they don't have the requested information, or hallucinate a response.
#
# ## TO-DO 🤔💭
# - Read and understand the system prompt
# - Observe how the capabilities of the model are limited when we ask for up-to-date information

# %%
# Let's create a travel agent with no tools
weather_uninformed_travel_agent = LLMAgent(model=model_name)

# Set an empty list of tools (no tools)
weather_uninformed_travel_agent.tools = []

# Define a system prompt for the travel agent
weather_uninformed_travel_agent.system_prompt = """
You are a helpful travel planning assistant.
Help users decide between travel destinations based on the weather forecast.
Answer in a friendly and concise manner (max 30 words).
"""

# Test the uninformed travel agent
question = "I'm hesitating between going to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?"

print("🤖 Testing our Weather-Uninformed Travel Agent:")
print("-" * 50)
response = weather_uninformed_travel_agent.chat(question)
# Out:
# 🤖 Testing our Weather-Uninformed Travel Agent:
# --------------------------------------------------
# - User said: I'm hesitating between going to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?
# - Available tools: []
# - Final Answer (no tools used): For potentially sunnier and milder weather, Rome is often a better bet than Paris next weekend. Enjoy the Eternal City!

# %% [markdown]
# **Solution**: Give LLMs access to tools so they can get updated information from APIs such as weather forecasts.
#
# ## How Tool Calling Works
#
# 1. **Define tools** - Tell the LLM what functions it can use
# 2. **LLM chooses** - It decides which tool to call based on the user's question
# 3. **Get results** - The function runs and returns real data
# 4. **Smart response** - LLM uses the fresh data to give informed answers
#
# Let's build a weather-informed travel agent! 🌦️✈️
#
# We'll start by creating a mock function that provides weather forecasts for the next N days in any city.
#
# > **Important Note**: The tools in this workshop are **mock functions** that generate random data for educational purposes. In real applications, these would connect to actual APIs like: OpenWeatherMap, Skyscanner, National railway APIs & Web search APIs to get current information
#
# ## TO-DO 🤔💭
# - Read and understand what the weather tool is doing
# - Pay attention to how the metadata (parameters schema and docstring) provide info to the model on how to use the tool
# - Look at how the tool is connected to the LLM Agent
# - Read and understand the system prompt of the LLM Agent
# - Observe how now the agent can provided guidance on where to travel based on the weather data

# %%
# Our First Tool: Weather Forecast

@add_parameters_schema( # Info for model about type and description of parameters
    city={"type": "string", "description": "City name"},
    days={"type": "integer", "description": "Number of days (1-7)"}
)
def get_weather_forecast(city: str, days: int = 3) -> str:
    """Get weather forecast for a city""" # Info for model about what the function does
    import random
    
    # Possible weather conditions
    conditions = ["Sunny", "Cloudy", "Rainy", "Snowy"]
    
    # Generate random forecast
    result = f"Weather for {city}:\n"
    for day in range(1, days + 1):
        weather = random.choice(conditions)
        temp = random.randint(5, 25)  # Temperature in Celsius
        result += f"Day {day}: {weather}, {temp}°C\n"
    
    return result

# %%
# Test the tool: weather forecast for Paris for 3 days
weather_forecast = get_weather_forecast("Paris", 3)
print(weather_forecast)
# Out:
# Weather for Paris:
# Day 1: Snowy, 24°C
# Day 2: Snowy, 16°C
# Day 3: Cloudy, 24°C

# %%
# Now let's create and test a travel agent that is weather-informed
weather_informed_travel_agent = LLMAgent(model=model_name)

# Connect the tools defined in the notebook
weather_informed_travel_agent.tools = [get_weather_forecast]

# Set the system prompt defined in the notebook
weather_informed_travel_agent.system_prompt = """
You are a helpful travel planning assistant.
Your task is to help users decide between travel destinations.
Use the tools provided to make an informed recommendation.
Answer in a friendly and concise manner (max 30 words).
"""
# Test our travel agent
question = """I'm hesitating between going to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?"""

print("🤖 Testing our Weather-Informed Travel Agent:")
print("-" * 50)

# Get a response from the travel agent
response = weather_informed_travel_agent.chat(question)
# Out:
# 🤖 Testing our Weather-Informed Travel Agent:
# --------------------------------------------------
# - User said: I'm hesitating between going to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?
# - Available tools: ['get_weather_forecast']
# - Tools called: ['get_weather_forecast', 'get_weather_forecast']
# - Executing get_weather_forecast with args: {'city': 'Paris', 'days': 3}
# - Tool result: Weather for Paris:
# Day 1: Snowy, 6°C
# Day 2: Cloudy, 15°C
# Day 3: Cloudy, 24°C
#
# - Executing get_weather_forecast with args: {'city': 'Rome', 'days': 3}
# - Tool result: Weather for Rome:
# Day 1: Rainy, 21°C
# Day 2: Cloudy, 18°C
# Day 3: Sunny, 9°C
#
# - Final Answer: Rome offers milder temperatures and less extreme weather, starting with rain then clearing up. Enjoy your trip!

# %% [markdown]
# # 🚀 Advanced Exercise: Compare Travel Options
#
# Now let's add flight and train price checking! Your agent will help users choose between different travel options.
#
# ## Your Tasks 📝
#
# 1. **Study the tools below** - See how they work
# 2. **Write a system prompt** - Tell your agent how to help users
# 3. **Connect the tools** - Add all tools to your agent
# 4. **Test it out** - Try different travel questions
#
# The tools give realistic prices and CO2 emissions. Your job: make an agent that helps users choose wisely! 🌱💰
#
# > **Remember**: These tools generate random data for learning purposes. Real travel agents would use live APIs to get actual prices, schedules, and availability from airlines, booking sites, and transportation providers.

# %%
# Tool 1: Flight Prices
@add_parameters_schema(
    origin={"type": "string", "description": "Departure city"},
    destination={"type": "string", "description": "Destination city"}
)
def get_flight_prices(origin: str, destination: str) -> str:
    """Get flight prices and environmental impact"""
    import random
    
    # Simple price calculation
    price = random.randint(150, 400)
    airline = random.choice(["BudgetAir", "SkyConnect", "EuroWings"])
    
    # Flight details
    hours = random.randint(2, 8)
    co2_kg = random.randint(80, 200)  # CO2 emissions in kg
    
    return f"✈️ Flight {origin} → {destination}: {airline} €{price} ({hours}h, CO2: {co2_kg}kg)"

# Test it!
print(get_flight_prices("Paris", "Rome"))
# Out:
# ✈️ Flight Paris → Rome: EuroWings €318 (8h, CO2: 184kg)

# %%
# Tool 2: Train Prices  
@add_parameters_schema(
    origin={"type": "string", "description": "Departure city"},
    destination={"type": "string", "description": "Destination city"}
)
def get_train_prices(origin: str, destination: str) -> str:
    """Get train prices and environmental impact"""
    import random
    
    # Some routes don't exist
    no_train_routes = [("London", "Rome"), ("Madrid", "Stockholm")]
    if (origin, destination) in no_train_routes or (destination, origin) in no_train_routes:
        return f"🚫 No train route from {origin} to {destination}"
    
    # Simple price calculation (usually cheaper than flights)
    price = random.randint(80, 250)
    operator = random.choice(["EuroRail", "HighSpeed", "RegionalTrain"])
    
    # Train details  
    hours = random.randint(4, 12)
    co2_kg = random.randint(10, 40)  # Much lower CO2 than flights!
    
    return f"🚂 Train {origin} → {destination}: {operator} €{price} ({hours}h, CO2: {co2_kg}kg)"

# Test it!
print(get_train_prices("Paris", "Rome"))
# Out:
# 🚂 Train Paris → Rome: HighSpeed €207 (12h, CO2: 37kg)

# %%
# TODO: STUDENT TASK - Create and configure your enhanced agent
# 1. Create a new LLMAgent instance
enhanced_travel_agent = LLMAgent(model=model_name)

# 2. Add the weather, flight and trains tool to the agent

# 3. Write your enhanced system prompt here to consider cost and sustainability
enhanced_travel_agent.system_prompt = """
Write your system prompt here!

Consider including:
- Your agent's role and personality
- How to balance cost vs environmental impact  
- What factors to prioritize (price, CO2, time, comfort)
- How to structure recommendations
- Tone (friendly, professional, expert, etc.)
"""

# %% [markdown]
# ## 🧪 Test Your Enhanced Agent
#
# Try different questions, ensure the agent uses the tools to get updated information, and that it replies as expected.
#
# **What to Notice:**
# - Does it check all options (weather, flights, trains)?
# - How does it explain trade-offs?
# - Is the advice helpful and clear?

# %%
# Test your enhanced travel agent here!
# Make sure you've completed the agent creation above first

test_question = """
I'm hesitating between traveling from Munich to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?
"""

enhanced_travel_agent.chat(test_question)
# Out:
# - User said:
# I'm hesitating between traveling from Munich to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?
#
# - Available tools: []
# - Final Answer (no tools used): That's a fantastic choice to make! Both Paris and Rome offer incredible experiences, and for a 3-day trip from Munich, you're in for a treat no matter which you pick.
#
# To help me give you the best recommendation, could you tell me a little more about what you're looking for in your trip? For example:
#
# *   **What are your main interests?** (e.g., art and museums, ancient history, food and wine, romance, shopping, nightlife, relaxation, iconic landmarks?)
# *   **What's your preferred pace?** (e.g., fast-paced sightseeing, leisurely strolls, a mix?)
# *   **Is budget a major concern?**
# *   **How do you prefer to travel?** (e.g., train for scenery/lower CO2, or flight for speed?)
#
# In the meantime, here's a general comparison to get you started:
#
# ---
#
# ### **Paris: The City of Lights and Romance**
#
# *   **Vibe & Experience:** Elegant, romantic, sophisticated, artistic, and fashionable. Known for its iconic landmarks, world-class museums, charming cafes, and beautiful architecture.
# *   **Key Attractions (for 3 days):** Eiffel Tower, Louvre Museum, Notre Dame (exterior), Arc de Triomphe, Champs-Élysées, Montmartre & Sacré-Cœur, Seine River cruise.
# *   **Food:** Gourmet dining, patisseries, boulangeries, crepes, cheese, wine.
# *   **Travel from Munich:**
#     *   **Train:** A viable and scenic option! High-speed trains (ICE/TGV) take around 6-7 hours with usually one change. This is generally the more environmentally friendly choice.
#     *   **Flight:** Around 1.5 hours flying time, plus airport transfers and security. Often quicker overall, but higher CO2 emissions.
# *   **Cost:** Can be on the higher side for accommodation and dining, but there are options for all budgets.
#
# ### **Rome: The Eternal City of History and Charm**
#
# *   **Vibe & Experience:** Ancient, bustling, vibrant, historical, and full of life. A city where history is literally around every corner, with a passionate culture and incredible food.
# *   **Key Attractions (for 3 days):** Colosseum & Roman Forum, Vatican City (St. Peter's Basilica, Vatican Museums, Sistine Chapel), Trevi Fountain, Pantheon, Spanish Steps, Trastevere neighborhood.
# *   **Food:** Authentic pasta, pizza, gelato, espresso, Roman-style artichokes, local wines.
# *   **Travel from Munich:**
#     *   **Train:** A much longer journey, typically 10-12+ hours with multiple changes, making it less practical for a short 3-day trip.
#     *   **Flight:** The most practical option, around 1.5 hours flying time, plus airport transfers.
# *   **Cost:** Can be slightly more budget-friendly than Paris for food and some accommodations, but popular areas can still be pricey.
#
# ---
#
# **To summarize based on general preferences:**
#
# *   **Choose Paris if you're looking for:** Romance, iconic art and museums, elegant architecture, high fashion, and a sophisticated culinary scene. You're also open to a longer but more environmentally friendly train journey.
# *   **Choose Rome if you're looking for:** Ancient history, awe-inspiring ruins, a vibrant and bustling atmosphere, incredible food at every turn, and a sense of timelessness. You're comfortable flying for speed.
#
# Let me know your preferences, and I can give you a more tailored recommendation!
# "That's a fantastic choice to make! Both Paris and Rome offer incredible experiences, and for a 3-day trip from Munich, you're in for a treat no matter which you pick.\n\nTo help me give you the best recommendation, could you tell me a little more about what you're looking for in your trip? For example:\n\n*   **What are your main interests?** (e.g., art and museums, ancient history, food and wine, romance, shopping, nightlife, relaxation, iconic landmarks?)\n*   **What's your preferred pace?** (e.g., fast-paced sightseeing, leisurely strolls, a mix?)\n*   **Is budget a major concern?**\n*   **How do you prefer to travel?** (e.g., train for scenery/lower CO2, or flight for speed?)\n\nIn the meantime, here's a general comparison to get you started:\n\n---\n\n### **Paris: The City of Lights and Romance**\n\n*   **Vibe & Experience:** Elegant, romantic, sophisticated, artistic, and fashionable. Known for its iconic landmarks, world-class museums, charming cafes, and beautiful architecture.\n*   **Key Attractions (for 3 days):** Eiffel Tower, Louvre Museum, Notre Dame (exterior), Arc de Triomphe, Champs-Élysées, Montmartre & Sacré-Cœur, Seine River cruise.\n*   **Food:** Gourmet dining, patisseries, boulangeries, crepes, cheese, wine.\n*   **Travel from Munich:**\n    *   **Train:** A viable and scenic option! High-speed trains (ICE/TGV) take around 6-7 hours with usually one change. This is generally the more environmentally friendly choice.\n    *   **Flight:** Around 1.5 hours flying time, plus airport transfers and security. Often quicker overall, but higher CO2 emissions.\n*   **Cost:** Can be on the higher side for accommodation and dining, but there are options for all budgets.\n\n### **Rome: The Eternal City of History and Charm**\n\n*   **Vibe & Experience:** Ancient, bustling, vibrant, historical, and full of life. A city where history is literally around every corner, with a passionate culture and incredible food.\n*   **Key Attractions (for 3 days):** Colosseum & Roman Forum, Vatican City (St. Peter's Basilica, Vatican Museums, Sistine Chapel), Trevi Fountain, Pantheon, Spanish Steps, Trastevere neighborhood.\n*   **Food:** Authentic pasta, pizza, gelato, espresso, Roman-style artichokes, local wines.\n*   **Travel from Munich:**\n    *   **Train:** A much longer journey, typically 10-12+ hours with multiple changes, making it less practical for a short 3-day trip.\n    *   **Flight:** The most practical option, around 1.5 hours flying time, plus airport transfers.\n*   **Cost:** Can be slightly more budget-friendly than Paris for food and some accommodations, but popular areas can still be pricey.\n\n---\n\n**To summarize based on general preferences:**\n\n*   **Choose Paris if you're looking for:** Romance, iconic art and museums, elegant architecture, high fashion, and a sophisticated culinary scene. You're also open to a longer but more environmentally friendly train journey.\n*   **Choose Rome if you're looking for:** Ancient history, awe-inspiring ruins, a vibrant and bustling atmosphere, incredible food at every turn, and a sense of timelessness. You're comfortable flying for speed.\n\nLet me know your preferences, and I can give you a more tailored recommendation!"

# %% [markdown]
# ## Provided solution

# %%
# Provided solution to the advanced travel agent task
# 1. Create a new LLMAgent instance
enhanced_travel_agent = LLMAgent(model=model_name)
# 2. Add the weather, flight and trains tool to the agent
enhanced_travel_agent.tools = [get_weather_forecast, get_flight_prices, get_train_prices]
# 3. Write your enhanced system prompt here to consider cost and sustainability
enhanced_travel_agent.system_prompt = """
You are an expert travel planning assistant.
Your task is to help users decide between travel destinations.
Use the tools provided to make an informed recommendation.
Prioritize affordable and low-CO2 options, but also consider user comfort.
Answer in a friendly and concise manner (max 50 words).
"""

# %%
# Test the provided solution
question = "I'm hesitating between traveling from Munich to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?"

print("🤖 Testing our Enhanced Travel Agent:")
print("-" * 50)
response = enhanced_travel_agent.chat(question)
# Out:
# 🤖 Testing our Enhanced Travel Agent:
# --------------------------------------------------
# - User said: I'm hesitating between traveling from Munich to Paris or Rome for a 3-day trip next weekend. Which destination should I choose?
# - Available tools: ['get_weather_forecast', 'get_flight_prices', 'get_train_prices']
# - Tools called: ['get_flight_prices', 'get_train_prices', 'get_weather_forecast', 'get_flight_prices', 'get_train_prices', 'get_weather_forecast']
# - Executing get_flight_prices with args: {'destination': 'Paris', 'origin': 'Munich'}
# - Tool result: ✈️ Flight Munich → Paris: EuroWings €158 (4h, CO2: 184kg)
# - Executing get_train_prices with args: {'destination': 'Paris', 'origin': 'Munich'}
# - Tool result: 🚂 Train Munich → Paris: RegionalTrain €90 (4h, CO2: 39kg)
# - Executing get_weather_forecast with args: {'city': 'Paris', 'days': 3}
# - Tool result: Weather for Paris:
# Day 1: Sunny, 10°C
# Day 2: Rainy, 23°C
# Day 3: Sunny, 9°C
#
# - Executing get_flight_prices with args: {'origin': 'Munich', 'destination': 'Rome'}
# - Tool result: ✈️ Flight Munich → Rome: EuroWings €266 (4h, CO2: 135kg)
# - Executing get_train_prices with args: {'destination': 'Rome', 'origin': 'Munich'}
# - Tool result: 🚂 Train Munich → Rome: HighSpeed €164 (8h, CO2: 10kg)
# - Executing get_weather_forecast with args: {'city': 'Rome', 'days': 3}
# - Tool result: Weather for Rome:
# Day 1: Rainy, 5°C
# Day 2: Cloudy, 7°C
# Day 3: Cloudy, 7°C
#
# - Final Answer: For an affordable, comfortable, and quicker trip, choose **Paris**! The train is only €90 and takes 4 hours, with much better weather (9-23°C, sunny days) compared to Rome's colder, rainier forecast and longer travel times.
